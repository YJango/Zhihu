# %%
import numpy as np
import re
import pandas as pd

# %%
with open('user.txt','r') as f:
    content = f.readlines()
    users = [{'name':content[i][:-1],'comment':content[i+2][:-1]} for i in range(len(content)-1) if content[i][:-1] == ' '.join(content[i+1].split(' ')[:-1])[:-1]]
    users_df = pd.DataFrame(users,columns=['name','comment']).drop_duplicates(subset='name').reset_index(drop=True)

# %%
# 不参加
off = ['沐沐','愤怒阿昌','影子猫','苏墨安Anny','MagicFriday','老瓜皮','小雨点','dtlsh110']

# %%
f_users_df = users_df.drop(users_df[users_df.name.isin(off)].index).reset_index(drop=True)

# %%
f_users_df
# Out:
#            name                                    comment
# 0    Ninetynine                                    我想要。。。。
# 1         不再是萌新             新版视频做的更好了。。。然后想帮女朋友要一张[捂脸][捂脸]
# 2           魏浩南                                    想去 [欢呼]
# 3         仗剑出白雪                                   大佬，我想要~！
# 4           凯恩博                                送我吧[惊喜][握手]
# 5         天涯羽伏麟                                   想要！！[赞同]
# 6        Caspar                                   举手🙋‍♂️想去
# 7      zc-brant                                      想要，老铁
# 8        lavoro                                        想要!
# 9       这条咸鱼好咸啊                                       大佬瞩目
# 10        如果有来生                                         想要
# 11       Austin                                     啊啊啊想要！
# 12        小伙子稳的                                     rua，想要
# 13    shengvaxy                          想要[大笑][酷][大笑][大笑]
# 14      踏破惊雷又为谁                                 想要，关注你很久了~
# 15        酒厂二锅头                                     想要[赞同]
# 16        请您安静点                                       啊，想要
# 17  Shawn Tsien                                   我要申请，谢谢！
# 18           雪子                                      想要[爱]
# 19         xjd1                            想要但充满了更多的未知与好奇。
# 20         当里个当  既然你送票不参加，那就证明这种形式高大上吹吹捧捧的会议没啥意思，别送我，我也不要…
# 21          刘晓庭       您好，我看过您的文章，很棒，可以送我一张票吗，我对这个活动有兴趣[赞同]
# 22          大猩猩                                         加一
# 23        喜欢井的鱼                                         想要
# 24        请叫我阿一                                   我也想要[可怜]
# 25         石上清泉                                    想要票[微笑]
# 26           天月                              大大，我我我我想要[可怜]
# 27      fff.zrx                                     举手！！🐵🐵
# 28          白雨桐                                         🙋🏻
# 29         声色犬马                            那时候应该在深圳，报名要一张哈
# ..          ...                                        ...
# 69          徐昊旻                                    在深圳，想要票
# 70         棠梨煎雪                                    学长好，想要票
# 71           热诚     大二学生想要票。竟然把自己的票送出去，不管怎样，先说声谢谢啦[害羞][害羞]
# 72           无常                            顺其自然，得之我幸，不得我命。
# 73         凌波微步                                 随缘，非常想去，谢谢
# 74         无间有三                               想要，但是顺其自然[酷]
# 75           断鸿                             想要票，收藏大佬的文章好久了
# 76         聪明的人                                 想去想去想去[爱心]
# 77      鱼鱼鱼鱼鱼y3                            虽然听不懂，但是还是好想去现场
# 78     Robin.QY                                    在深圳，想要票
# 79          吻红尘                                 base深圳，想去听
# 80           紫苏                                 想去想去，好运+++
# 81   LittleStar                          失之我命，得之我幸[赞同][赞同]
# 82          神无月                                        万一呢
# 83           凌云                                         想要
# 84          YOU                            我我我我我，想去！！！[大哭]
# 85      peterhe                           我好想去[捂脸][捂脸][捂脸]
# 86           而亦               举手举手举手~~如果中了我就马上去请假买票打包行李[爱]
# 87          赫赫赫                                        举个手
# 88           白家                                        学长好
# 89        junko                        爱ai呦，要去看看，嘿嘿嘿(º﹃º )
# 90          竹马君                                        举手手
# 91         A比C低              想去，但刚刚高中毕业，去了也听不懂[捂脸][捂脸][捂脸]
# 92          无极宇                                     想去[可怜]
# 93         光之君王                                        举手🙌
# 94      进击的巨人LJ                                 不知道还有没有机会？
# 95     别放香菜别放香菜                          刚考上计科研究生表示想去🙋🏻‍♂️
# 96       Truman            你好，我刚刚看了下参与者名单，发现没有我怎么办[大哭][大哭]
# 97        有点小烦躁            你好，我刚刚看了下参与者名单，发现没有我怎么办[大哭][大哭]
# 98       拉普拉斯同学            你好，我刚刚看了下参与者名单，发现没有我怎么办[大哭][大哭]
#
# [99 rows x 2 columns]

# %%
f_users_df.to_csv('allusers.csv',index=False, encoding='utf_8_sig')

# %%
# 这仅仅是个测试，展示怎么抽的
import time, datetime
startTime = datetime.datetime(2019, 6, 12, 12, 59, 0) #系统时间慢了，应该是
print('当前时间: %s' %datetime.datetime.now())
print('开始时间: %s' %startTime)
while datetime.datetime.now() < startTime:
    time.sleep(1)
print('开始时间: %s' %startTime)
print('获票知友: %s' %np.random.choice(f_users_df['name'],size=2,replace=False))
# Out:
# 当前时间: 2019-06-12 12:02:22.912651
# 开始时间: 2019-06-12 12:59:00
# 开始时间: 2019-06-12 12:59:00
# 获票知友: ['迷鹿' '向心力']
