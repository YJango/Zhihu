# %%
import numpy as np
import re
import pandas as pd

# %%
with open('users.txt','r') as f:
    content = f.readlines()
    users = [{'name':content[i][:-1],'comment':content[i+2][:-1]} for i in range(len(content)-1) if content[i][:-1] == ' '.join(content[i+1].split(' ')[:-1])[:-1]]
    users_df = pd.DataFrame(users,columns=['name','comment']).drop_duplicates(subset='name').reset_index(drop=True)

# %%
users_df
# Out:
#             name                 comment
# 0          沐沐呵呵哒                   棒呆！！！
# 1    LMdeLiangMi                  噫！想要哈哈
# 2             赵澈                      举手
# 3           Leon                     留名。
# 4         hao li                      支持
# 5         lumial                    [吃瓜]
# 6          Kerry                     哇想要
# 7      quoniammm  现在在深圳从事自然语言处理方面的工作 想去～
# 8          骑鱼的基德                  拉低中奖率😏
# 9            郑谨立     占位报名。。。ps：挑选的随机算法是？
# 10          Evan       就在深圳附近，想去！！举手 [棒]
# 11            超迁           深大学生 想去见识见识😂😂
# 12          松鼠先生                  留名查看表情
# 13         厚度有影响      想去，舉手-uk大學ai lab成員
# 14         我有爱姿病         想去，正好6月底去深圳学校实习
# 15      bigwhite                      想去
# 16            匡猫             留名 希望有机会去学习
# 17           肖华亮                     想去～
# 18  jianqiao sun                      想去
# 19            章黎                    想去~😃
# 20          无与伦比                    选我选我
# 21         科学Jia       支持我男神随机去重的决定！哈哈哈哈
# 22            不懂                     举手🙋
# 23         stone                我在深圳，想去！
# 24       VanNess                 如果有机会的话
# 25           张晓燕                     想去哈
# 26        记忆的抽象画                  想去，举手🙌
# 27     AlexYoung                     举手！

# %%
#不参加['沐沐呵呵哒','lumial','科学Jia','hao li']

# %%
f_users_df = users_df.drop(users_df[users_df.name.isin(['沐沐呵呵哒','lumial','科学Jia','hao li'])].index).reset_index(drop=True)

# %%
f_users_df
# Out:
#             name                 comment
# 0    LMdeLiangMi                  噫！想要哈哈
# 1             赵澈                      举手
# 2           Leon                     留名。
# 3          Kerry                     哇想要
# 4      quoniammm  现在在深圳从事自然语言处理方面的工作 想去～
# 5          骑鱼的基德                  拉低中奖率😏
# 6            郑谨立     占位报名。。。ps：挑选的随机算法是？
# 7           Evan       就在深圳附近，想去！！举手 [棒]
# 8             超迁           深大学生 想去见识见识😂😂
# 9           松鼠先生                  留名查看表情
# 10         厚度有影响      想去，舉手-uk大學ai lab成員
# 11         我有爱姿病         想去，正好6月底去深圳学校实习
# 12      bigwhite                      想去
# 13            匡猫             留名 希望有机会去学习
# 14           肖华亮                     想去～
# 15  jianqiao sun                      想去
# 16            章黎                    想去~😃
# 17          无与伦比                    选我选我
# 18            不懂                     举手🙋
# 19         stone                我在深圳，想去！
# 20       VanNess                 如果有机会的话
# 21           张晓燕                     想去哈
# 22        记忆的抽象画                  想去，举手🙌
# 23     AlexYoung                     举手！

# %%
import time, datetime
startTime = datetime.datetime(2018, 6, 5, 9, 0, 0) #9点实际上是我电脑上18点（北京时间17点）
print('当前时间: %s' %datetime.datetime.now())
print('开始时间: %s' %startTime)
while datetime.datetime.now() < startTime:
    time.sleep(1)
print('开始时间: %s' %startTime)
print('获票知友: %s' %np.random.choice(f_users_df['name']))
# Out:
# 当前时间: 2018-06-05 08:57:51.237492
# 开始时间: 2018-06-05 09:00:00
# 开始时间: 2018-06-05 09:00:00
# 获票知友: stone
